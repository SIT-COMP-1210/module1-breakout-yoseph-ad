# %% [markdown]
# <a href="https://colab.research.google.com/github/SIT-COMP-1210/module1-breakout-yoseph-ad/blob/main/comp1210_module1_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SIT-COMP-1210/Module1-Breakout-yoseph-ad.git
# Out:
# Cloning into 'Module1-Breakout-yoseph-ad'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 6 (from 2)
# Receiving objects: 100% (12/12), 4.91 KiB | 4.91 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# **Instructions**
#
#
# *   Replace "{YourGitHubUser}" with your GitHub username
# *   Run the cell above to clone this .ipynb file to your git repository
#
#
# *   Once you are done completing the assignment below, click on "File" above, from the dropdown select "Save a copy in GitHub"
# *   Edit the commit message to reflect your latest change (e.g "Submitting Breakout Session Assignment")
#
#
# *   Commit your change
#
#
# *   Lastly, go to GitHub Classroom repository to confirm your file submission

# %% [markdown]
# **Practice Problems**

# %% [markdown]
# 1) What is wrong with this code?
#
# *   print("Hello World)
# * Quotation is not closed the correct one is
#  print("Hello World")

# %% [markdown]
# 2. Print all the values below
#
# *   Hello Word
# *   3
# *  2+2 <br>
# Answer
# * print ("Hello Word")
# * print(3)
# * print(2+2)

# %% [markdown]
# 3. Write a code that prints:
#
# print("Hello") <br>
# print("Hello") <br>
# print("Hello")
# *   Hello
#
#       Hello
#
#       Hello

# %% [markdown]
# 4. Then combine it to 1 line:
#
# print("HelloHelloHello")
#
#
# *   HelloHelloHello

# %% [markdown]
# 5. What will be printed when you run:
#
#
#
#   *   print("2" + "2")
#   *   print(2 + 2)
#
#   *   print("A")
#   *   print("B")
#
#
#   *   print("A" + "B")
#
#   Outputs
#
#   * 22
#   * 4
#   * A
#   * B
#   * AB
